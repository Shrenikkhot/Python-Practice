# %%
try:
    name = str(input('Enter your name -'))
    age = int(input('enter your age - '))
    print(f'your name is {name} and age {age}')
except:
    print('enter only number = try again')
    age = int(input('enter your age'))
    print(f'your name is {name} and age {age}')
# Out:
# Enter your name -shrenik
# enter your age - 45
# your name is shrenik and age 45

# %%
try:
    height = int(input('enter your height'))
    age = int(input('enter your age'))
    result = height/age
    print(f'Your BMI = {result}')
except ValueError:
    print('Enter Only Number')
except ZeroDivisionError:
    print('Do not enter Zero')
# Out:
# enter your height45
# enter your age45
# Your BMI = 1.0

# %%
try:
    height = int(input('enter your height'))
    age = int(input('enter your age'))
    result = height/age
    print(f'Your BMI = {result}')
except Exception:
    print('this is error')
# Out:
# enter your height54
# enter your age454
# Your BMI = 0.11894273127753303

# %%
try:
    height = int(input('enter your height'))
    age = int(input('enter your age'))
    result = height/age
    print(f'Your BMI = {result}')
except (ZeroDivisionError,ValueError):
    print('Enter Only Number / Do not enter Zero')
else: 
    print('Successful-----')
# Out:
# enter your height55
# enter your age55
# Your BMI = 1.0
# Successful-----

# %%
try:
    height = int(input('enter your height'))
    age = int(input('enter your age'))
    result = height/age
    print(f'Your BMI = {result}')
except (ZeroDivisionError,ValueError):
    print('Enter Only Number / Do not enter Zero')
finally:
    print('Successful-----')
# Out:
# enter your height46
# enter your age45
# Your BMI = 1.0222222222222221
# Successful-----
