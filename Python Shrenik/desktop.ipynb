# %%
data = []
print(type(data))
# Out:
# <class 'list'>

# %%
data = ["java","c++", "python","r","jsp","rubby"]
print(data)
# Out:
# ['java', 'c++', 'python', 'r', 'jsp', 'rubby']

# %%
print(data[2])
print(data[-3])
# Out:
# python
# r

# %%
print(data[2:4])
print(data[:4])
print(data[3:])
print(data[:])
# Out:
# ['python', 'r']
# ['java', 'c++', 'python', 'r']
# ['r', 'jsp', 'rubby']
# ['java', 'c++', 'python', 'r', 'jsp', 'rubby']

# %%
data = ["java","c++", "python","r","jsp","rubby"]
#update
data[3]="go"
print(data)
# Out:
# ['java', 'c++', 'python', 'go', 'jsp', 'rubby']

# %%
#append
data.append("Julia")
print(data)
# Out:
# ['java', 'c++', 'python', 'go', 'jsp', 'rubby', 'Julia']

# %%
#extend()
data.extend(["JSF", "Spring","API"])
print(data)
# Out:
# ['java', 'c++', 'python', 'go', 'jsp', 'rubby', 'Julia', 'JSF', 'Spring', 'API']

# %%
#insert 
data.insert(3,"CWPC")
print(data)
# Out:
# ['java', 'c++', 'python', 'CWPC', 'go', 'jsp', 'rubby', 'Julia', 'JSF', 'Spring', 'API']

# %%
#remove()
data.remove("java")
print(data)
# Out:
# ['c++', 'python', 'CWPC', 'go', 'jsp', 'rubby', 'Julia', 'JSF', 'Spring', 'API']

# %%
#pop()
data.pop()
print(data)
# Out:
# ['c++', 'python', 'CWPC', 'go', 'jsp', 'rubby', 'Julia', 'JSF']

# %%
#index()
print(data.index("python"))
# Out:
# 1

# %%
data = ['c++', 'python', 'CWPC', 'go', 'jsp', 'rubby', 'Julia', 'Julia','Julia','Julia']
#count()
print(data.count("Julia"))
# Out:
# 4

# %%
#sort()
data = [21,222,1,2,3,4,1,5,6,7,2,3]
data.sort()
print(data)
#reverse()
data.reverse()
print(data)
# Out:
# [1, 1, 2, 2, 3, 3, 4, 5, 6, 7, 21, 222]
# [222, 21, 7, 6, 5, 4, 3, 3, 2, 2, 1, 1]

# %%
#copy()
d1=data.copy()
print(d1)
# Out:
# [222, 21, 7, 6, 5, 4, 3, 3, 2, 2, 1, 1]

# %%
#clear()
data.clear()
print(data)
# Out:
# []

# %%
data = [21,222,1,2,3,4,1,5,6,7,2,3]
print(min(data))
print(max(data))
print(sum(data))
print(len(data))
# Out:
# 1
# 222
# 277
# 12

# %%
data = "codeswithshrenik"
print(len(data))
# Out:
# 16
