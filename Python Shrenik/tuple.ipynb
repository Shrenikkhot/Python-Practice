# %%
data =(45,)
print(type(data))
# Out:
# <class 'tuple'>

# %%
data = 45,
print(type(data))
# Out:
# <class 'tuple'>

# %%
data = (45,65,56,78,78,90,78)
print(type(data))
# Out:
# <class 'tuple'>

# %%
print(data[2])
# Out:
# 56

# %%
print(data.count(78))
# Out:
# 3

# %%
print(data.index(56))
# Out:
# 2
