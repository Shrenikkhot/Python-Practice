# %%
#empty set 
data = set()
print(type(data))
# Out:
# <class 'set'>

# %%
data = {1,2,3,4,5,6,7,12,1,21,21,2,1,22,2,2,2,2,22,2,3,4,5,6}
print(data)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 12, 21, 22}

# %%
data = [1,2,3,4,5,6,7,12,1,21,21,2,1,22,2,2,2,2,22,2,3,4,5,6]
data_set = set(data)
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 12, 21, 22}

# %%
#add
data_set.add(898)
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 898, 12, 21, 22}

# %%
#update
data_set.update([222,45,49])
print(data_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 898, 12, 45, 49, 21, 22, 222}

# %%
data = list(data_set)
print(data)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 898, 12, 45, 49, 21, 22, 222]

# %%
print(data[5:8])
print(data[7])
# Out:
# [6, 7, 898]
# 898

# %%
#discard
data = {12,1,14,15,13,12,1,2}
data.discard(1)
print(data)
# Out:
# {2, 12, 13, 14, 15}

# %%
data = {12,1,14,15,13,12,1,2}
data.remove(12)
print(data)
# Out:
# {1, 2, 13, 14, 15}

# %%
#pop
data.pop()
print(data)
# Out:
# {2, 13, 14, 15}

# %%
#clear 
data.clear()
print(data)
# Out:
# set()

# %%
data
# Out:
# set()
