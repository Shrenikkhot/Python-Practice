# %%
data = {
        'Name':'Joy',
        'Age' : 23,
        'Height':5.6
}

# %%
print(data)
# Out:
# {'Name': 'Joy', 'Age': 23, 'Height': 5.6}

# %%
#access data
print(data['Name'])
# Out:
# Joy

# %%
#update data
data['Age']=18
print(data)
# Out:
# {'Name': 'Joy', 'Age': 18, 'Height': 5.6}

# %%
#add new data 
data['city']='Mumbai'
print(data)
# Out:
# {'Name': 'Joy', 'Age': 18, 'Height': 5.6, 'city': 'Mumbai'}

# %%
#keys ()
print(data.keys())
# Out:
# dict_keys(['Name', 'Age', 'Height', 'city'])

# %%
#values()
print(data.values())
# Out:
# dict_values(['Joy', 18, 5.6, 'Mumbai'])

# %%
#items()
print(data.items())
# Out:
# dict_items([('Name', 'Joy'), ('Age', 18), ('Height', 5.6), ('city', 'Mumbai')])

# %%
#get(key,default())
print(data.get('Age'))
# Out:
# 18

# %%
#pop(key,default)
data.pop('Age')
# Out:
# 18

# %%
print(data)
# Out:
# {'Name': 'Joy', 'Height': 5.6, 'city': 'Mumbai'}

# %%
data = {
        "Name": "Kandivali RS",
        "Description": 'null',
        "BranchType": "Sub Post Office",
        "DeliveryStatus": "Non-Delivery",
        "Circle": "Maharashtra",
        "District": "Mumbai",
        "Division": "Mumbai  North West",
        "Region": "Mumbai",
        "Block": "Mumbai",
        "State": "Maharashtra",
        "Country": "India",
        "Pincode": "400067"
}

# %%
print(data.keys())
# Out:
# dict_keys(['Name', 'Description', 'BranchType', 'DeliveryStatus', 'Circle', 'District', 'Division', 'Region', 'Block', 'State', 'Country', 'Pincode'])

# %%
for i in data:
    print(i," = ",data[i])
# Out:
# Name  =  Kandivali RS
# Description  =  null
# BranchType  =  Sub Post Office
# DeliveryStatus  =  Non-Delivery
# Circle  =  Maharashtra
# District  =  Mumbai
# Division  =  Mumbai  North West
# Region  =  Mumbai
# Block  =  Mumbai
# State  =  Maharashtra
# Country  =  India
# Pincode  =  400067

# %%
print(data.get(i))
# Out:
# Kandivali RS

# %%
for i in data:
    print(i," = ",data.get(i))
# Out:
# Name  =  Kandivali RS
# Description  =  null
# BranchType  =  Sub Post Office
# DeliveryStatus  =  Non-Delivery
# Circle  =  Maharashtra
# District  =  Mumbai
# Division  =  Mumbai  North West
# Region  =  Mumbai
# Block  =  Mumbai
# State  =  Maharashtra
# Country  =  India
# Pincode  =  400067

# %%
for k,v in data.items():
    print(k," = ",v)
# Out:
# Name  =  Kandivali RS
# Description  =  null
# BranchType  =  Sub Post Office
# DeliveryStatus  =  Non-Delivery
# Circle  =  Maharashtra
# District  =  Mumbai
# Division  =  Mumbai  North West
# Region  =  Mumbai
# Block  =  Mumbai
# State  =  Maharashtra
# Country  =  India
# Pincode  =  400067
