# %%
#write file 
file = open('cwsk.txt','w')
file.write("Welcome to python programming.....\n")
file.write("Welcome to JAVA programming.....\n")
file.write("Welcome to C++ programming....\n")
file.close()

# %%
#read file 
file = open('cwsk.txt','r')
data = file.read()
print(data)
# Out:
# Welcome to python programming.....
# Welcome to JAVA programming.....
# Welcome to C++ programming....

# %%
#append file a
file = open('cwsk.txt','a')
file.write('Java - is best.......\n')
file.write('Python is basic....\n')
file.close()

# %%
#write 
with open('cwsk.txt','r') as file:
    print(file.read())
# Out:
# Welcome to python programming.....
# Welcome to JAVA programming.....
# Welcome to C++ programming....
# Java - is best.......
# Python is basic....
