# %%
try:
    name = str(input('Enter your Name'))
    age =int(input('Enter your Age'))
    height = int(input('Enter your Height'))
    BMI = age/height
    print(f'BMI ={BMI}')
    print(f'your name is {name} and age{age},height {height}')
except ValueError:
    print('Enter only number - plz')

    name = str(input('Enter your Name'))
    age =int(input('Enter your Age'))
    height = int(input('Enter your Height'))
    BMI = age/height
    print(f'BMI ={BMI}')
    print(f'your name is {name} and age{age},height {height}')
except ZeroDivisionError:
    print('do not enter zero-- please')
# Out:
# Enter your NameShrenik
# Enter your Ageshrenik
# Enter only number - plz
